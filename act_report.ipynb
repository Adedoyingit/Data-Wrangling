# %% [markdown]
# ## Report: act_report

# %% [markdown]
# I gathered WeRateDogs data using three different formats, I assessed the data by looking for quality and tidiness isssues which was later cleaned during the cleaning process (defining the issues, writing an executable code and test if the code works). In carrying out the wrangling process I got some insights from the data which I discuss below.

# %% [markdown]
# 1.![img_num%20vis.png](attachment:img_num%20vis.png)
# This graph represents the img_num column. It communicates the frequencies of the values in the img_column. We could see from the graph that one (1) has the highest frequency.

# %% [markdown]
# 2.![Favorite_vis.png](attachment:Favorite_vis.png)
# The graph above communicates that favorite_count between 0 and 10000 are higher compared to the other favorite_count

# %% [markdown]
# #### Major insights I got from the data includes:

# %% [markdown]
# 1.The pupper has the highest count of the other dog_types (doggo, puppo, and floofer).

# %% [markdown]
# ![dog_type%20vis-2.png](attachment:dog_type%20vis-2.png)

# %% [markdown]
# 2.The img_num does not have an effect on the number of retweet_count

# %% [markdown]
# ![img_retweet%20vis.png](attachment:img_retweet%20vis.png)

# %% [markdown]
# The number of images does not influence the number of retweet_count. As shown above, one(1) image got upto 7000 retweets

# %% [markdown]
# 3.The graph below shows the relationship between retweet_count and favorite_count

# %% [markdown]
# ![fav&retw.png](attachment:fav&retw.png)

# %% [markdown]
# We infer from the graph that there is a positive correlation between retweet_count and favorite_count

# %% [markdown]
# ### Conclusion
# Data Wrangling was done using some python libraries. Other information in the data can be visualized rather than the few I have done here. For example, we can find the dog with the higest rating, and we can also find the relationship between the retweet_count and favorite_count and so on
